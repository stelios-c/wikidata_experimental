# %% [markdown]
# During the Green Software foundation meetup at the university of Edinburgh, I had some conversations on blocking of bot traffic, and I wanted to check if the university website blocked traffic the same way Wikipedia blocks it, hence the tests below

# %%
import pandas as pd

# %%
ed_url='https://information-services.ed.ac.uk/computing/audio-visual-multi-media/web-hosting/using-web-hosting'

# %%
ed_tables=pd.read_html(ed_url)

# %%
ed_tables[0]
# Out:
#   Server Technology                               Supported Version
# 0            Apache                                             2.4
# 1               PHP  7.3 Native. Versions 5.6 to 8.3 also available
# 2           MariaDB                                    MariaDB 10.6
# 3            Python                                      2.7 to 3.9

# %% [markdown]
# Note all versions of Python listed were out of support at the time :(

# %%
# !wget https://information-services.ed.ac.uk/sites/default/files/styles/banner_1500x275/public/2024-10/1500x275image5_2_5_0.jpg.webp
# Out:
# --2026-09-04 20:46:33--  https://information-services.ed.ac.uk/sites/default/files/styles/banner_1500x275/public/2024-10/1500x275image5_2_5_0.jpg.webp
# Resolving information-services.ed.ac.uk (information-services.ed.ac.uk)... 2620:12a:8000::4, 2620:12a:8001::4, 23.185.0.4
# Connecting to information-services.ed.ac.uk (information-services.ed.ac.uk)|2620:12a:8000::4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 47860 (47K) [image/webp]
# Saving to: ‘1500x275image5_2_5_0.jpg.webp’
#
# 1500x275image5_2_5_ 100%[===================>]  46.74K  --.-KB/s    in 0.02s
#
# 2026-09-04 20:46:33 (2.26 MB/s) - ‘1500x275image5_2_5_0.jpg.webp’ saved [47860/47860]
